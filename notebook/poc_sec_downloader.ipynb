# %%
from sec_edgar_downloader import Downloader

dl = Downloader("MyCompanyName", "my.email@domain.com")

# %%
dl.get("10-K", "MSFT", limit=1)
# Out:
# 1

# %%
import requests
import pandas as pd
from typing import List, Dict
import yfinance as yf
import sec_edgar_downloader as sec

def lookup_company_info(isins: List[str]) -> List[Dict]:
    """
    Retrieve company information for a list of ISINs.
    
    Parameters:
    isins (List[str]): List of International Securities Identification Numbers (ISINs)
    
    Returns:
    List[Dict]: List of dictionaries containing company information
    """
    company_info_list = []
    
    for isin in isins:
        company_info = {
            'ISIN': isin,
            'Company Name': None,
            'Website': None,
            'CIK': None
        }
        
        try:
            # First, try to get info using yfinance
            ticker_symbol = None
            
            # Attempt to convert ISIN to ticker
            try:
                ticker = yf.Ticker(isin)
                info = ticker.info
                
                # Extract company name
                if 'longName' in info and info['longName']:
                    company_info['Company Name'] = info['longName']
                
                # Extract website
                if 'website' in info and info['website']:
                    company_info['Website'] = info['website']
                
                # Try to get ticker symbol
                ticker_symbol = ticker.ticker
            except Exception as yf_error:
                print(f"YFinance lookup failed for {isin}: {yf_error}")
            
            # If ticker is available, try SEC Edgar lookup
            if ticker_symbol:
                try:
                    # Initialize SEC Edgar downloader
                    dl = Downloader("MyCompanyName", "my.email@domain.com")
                    
                    # Get company information from SEC
                    company_info['CIK'] = dl.get_cik_by_ticker(ticker_symbol)
                except Exception as sec_error:
                    print(f"SEC Edgar lookup failed for {ticker_symbol}: {sec_error}")
            
            company_info_list.append(company_info)
        
        except Exception as e:
            print(f"Error processing ISIN {isin}: {e}")
            company_info_list.append(company_info)
    
    return company_info_list

def main():
    # Example list of ISINs
    example_isins = [
        'US0378331005',  # Apple
        'US5949181045',  # Microsoft
        'US88160R1014'   # Tesla
    ]
    
    # Get company information
    results = lookup_company_info(example_isins)
    
    # Convert to DataFrame for easy viewing
    df = pd.DataFrame(results)
    print(df)
    
    # Optional: Save to CSV
    df.to_csv('company_info.csv', index=False)

# %%
main()
# Out:
# SEC Edgar lookup failed for AAPL: 'Downloader' object has no attribute 'get_cik_by_ticker'
# SEC Edgar lookup failed for MSFT: 'Downloader' object has no attribute 'get_cik_by_ticker'
# SEC Edgar lookup failed for TSLA: 'Downloader' object has no attribute 'get_cik_by_ticker'
#            ISIN           Company Name                    Website   CIK
# 0  US0378331005             Apple Inc.      https://www.apple.com  None
# 1  US5949181045  Microsoft Corporation  https://www.microsoft.com  None
# 2  US88160R1014            Tesla, Inc.      https://www.tesla.com  None

# %%
import requests
import json

def get_cik_by_ticker(ticker: str) -> str:
    """
    Retrieve CIK (Central Index Key) for a given stock ticker.
    
    Args:
        ticker (str): Stock ticker symbol
    
    Returns:
        str: CIK number or None if not found
    """
    # SEC EDGAR company tickers mapping file
    tickers_url = "https://www.sec.gov/files/company_tickers.json"
    
    try:
        # Fetch the tickers JSON
        response = requests.get(tickers_url, headers={
            'User-Agent': 'Your Name your.email@example.com'
        })
        
        # Raise an exception for bad responses
        response.raise_for_status()
        
        # Parse the JSON response
        tickers_data = response.json()
        
        # Normalize ticker to uppercase
        ticker = ticker.upper()
        
        # Search for the CIK
        for key, company_info in tickers_data.items():
            if company_info['ticker'] == ticker:
                # Pad CIK with zeros to ensure 10 digits
                return str(company_info['cik_str']).zfill(10)
        
        # If ticker not found
        return None
    
    except Exception as e:
        print(f"Error retrieving CIK for {ticker}: {e}")
        return None

def get_company_info_by_cik(cik: str) -> dict:
    """
    Retrieve basic company information using CIK.
    
    Args:
        cik (str): CIK number
    
    Returns:
        dict: Company information
    """
    # Ensure CIK is padded to 10 digits
    cik = str(cik).zfill(10)
    
    # Construct SEC EDGAR company information URL
    url = f"https://data.sec.gov/submissions/CIK{cik}.json"
    
    try:
        # Fetch company information
        response = requests.get(url, headers={
            'User-Agent': 'Your Name your.email@example.com'
        })
        
        # Raise an exception for bad responses
        response.raise_for_status()
        
        # Parse the JSON response
        company_data = response.json()
        
        # Extract relevant information
        return {
            'name': company_data.get('name', 'N/A'),
            'ticker': company_data.get('tickers', ['N/A'])[0],
            'sic': company_data.get('sic', 'N/A'),
            'website': company_data.get('website', 'N/A')
        }
    
    except Exception as e:
        print(f"Error retrieving company info for CIK {cik}: {e}")
        return {}

def main():
    # Example usage
    tickers = ['AAPL', 'MSFT', 'GOOGL']
    
    for ticker in tickers:
        # Get CIK
        cik = get_cik_by_ticker(ticker)
        
        if cik:
            print(f"\nTicker: {ticker}")
            print(f"CIK: {cik}")
            
            # Get additional company info
            company_info = get_company_info_by_cik(cik)
            
            # Print company details
            for key, value in company_info.items():
                print(f"{key.capitalize()}: {value}")
        else:
            print(f"Could not find CIK for {ticker}")

# %%
main()
# Out:
# Ticker: AAPL
# CIK: 0000320193
# Name: Apple Inc.
# Ticker: AAPL
# Sic: 3571
# Website:
#
# Ticker: MSFT
# CIK: 0000789019
# Name: MICROSOFT CORP
# Ticker: MSFT
# Sic: 7372
# Website:
#
# Ticker: GOOGL
# CIK: 0001652044
# Name: Alphabet Inc.
# Ticker: GOOGL
# Sic: 7370
# Website:

# %%
dat = yf.Ticker("MSFT")
dat.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and power automate; and on-premises ERP and CRM applications. The Intelligent Cloud segment offers server products and cloud services, such as azure and other cloud services; SQL and windows server, visual studio, system center, and related client access licenses, as well as nuance and GitHub; and enterprise services including enterprise support services, industry solutions, and nuance professional services. The More Personal Computing segment offers Windows, including windows OEM licensing and other non-volume licensing of the Windows operating system; Windows commercial comprising volume licensing of the Windows operating system, windows cloud services, and other Windows commercial offerings; patent licensing; and windows Internet of Things; and devices, such as surface, HoloLens, and PC accessories. Additionally, this segment provides gaming, which includes Xbox hardware and content, and first- and third-party content; Xbox game pass and other subscriptions, cloud gaming, advertising, third-party disc royalties, and other cloud services; and search and news advertising, which includes Bing, Microsoft News and Edge, and third-party affiliates. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online, and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.',
#  'fullTimeEmployees': 228000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Satya  Nadella',
#    'age': 57,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'totalPay': 7869791,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bradford L. Smith LCA',
#    'age': 65,
#    'title': 'President & Vice Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2024,
#    'totalPay': 4755618,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Amy E. Hood',
#    'age': 52,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'totalPay': 4704250,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Judson B. Althoff',
#    'age': 50,
#    'title': 'Executive VP & Chief Commercial Officer',
#    'yearBorn': 1974,
#    'fiscalYear': 2024,
#    'totalPay': 4534974,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Christopher David Young',
#    'age': 52,
#    'title': 'Executive Officer',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'totalPay': 2993772,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Carolina  Dybeck Happe',
#    'age': 52,
#    'title': 'Executive VP & COO',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alice L. Jolla',
#    'age': 58,
#    'title': 'Corporate VP & Chief Accounting Officer',
#    'yearBorn': 1966,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James Kevin Scott',
#    'age': 52,
#    'title': 'Executive VP of AI & CTO',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Brett  Iversen',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hossein  Nowbar',
#    'title': 'Chief Legal Officer',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 9,
#  'boardRisk': 5,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 2,
#  'overallRisk': 3,
#  'governanceEpochDate': 1740787200,
#  'compensationAsOfEpochDate': 1735603200,
#  'irWebsite': 'http://www.microsoft.com/investor/default.aspx',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 391.26,
#  'open': 395.4,
#  'dayLow': 389.81,
#  'dayHigh': 395.4,
#  'regularMarketPreviousClose': 391.26,
#  'regularMarketOpen': 395.4,
#  'regularMarketDayLow': 389.81,
#  'regularMarketDayHigh': 395.4,
#  'dividendRate': 3.32,
#  'dividendYield': 0.85,
#  'exDividendDate': 1747267200,
#  'payoutRatio': 0.2482,
#  'fiveYearAvgDividendYield': 0.85,
#  'beta': 0.914,
#  'trailingPE': 31.7,
#  'forwardPE': 26.292976,
#  'volume': 20132071,
#  'regularMarketVolume': 20132071,
#  'averageVolume': 22688612,
#  'averageVolume10days': 24708840,
#  'averageDailyVolume10Day': 24708840,
#  'bid': 375.25,
#  'ask': 414.98,
#  'bidSize': 1,
#  'askSize': 1,
#  'marketCap': 2922148790272,
#  'fiftyTwoWeekLow': 376.91,
#  'fiftyTwoWeekHigh': 468.35,
#  'priceToSalesTrailing12Months': 11.1616745,
#  'fiftyDayAverage': 408.9458,
#  'twoHundredDayAverage': 423.36435,
#  'trailingAnnualDividendRate': 3.16,
#  'trailingAnnualDividendYield': 0.008076471,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 2939973795840,
#  'profitMargins': 0.35428002,
#  'floatShares': 7423649000,
#  'sharesOutstanding': 7433979904,
#  'sharesShort': 66334396,
#  'sharesShortPriorMonth': 62492832,
#  'sharesShortPreviousMonthDate': 1738281600,
#  'dateShortInterest': 1740700800,
#  'sharesPercentSharesOut': 0.0089,
#  'heldPercentInsiders': 0.00062,
#  'heldPercentInstitutions': 0.74447,
#  'shortRatio': 2.68,
#  'shortPercentOfFloat': 0.0089,
#  'impliedSharesOutstanding': 7433979904,
#  'bookValue': 40.712,
#  'priceToBook': 9.655138,
#  'lastFiscalYearEnd': 1719705600,
#  'nextFiscalYearEnd': 1751241600,
#  'mostRecentQuarter': 1735603200,
#  'earningsQuarterlyGrowth': 0.102,
#  'netIncomeToCommon': 92749996032,
#  'trailingEps': 12.4,
#  'forwardEps': 14.95,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1045526400,
#  'enterpriseToRevenue': 11.23,
#  'enterpriseToEbitda': 20.698,
#  '52WeekChange': -0.074729204,
#  'SandP52WeekChange': 0.086116076,
#  'lastDividendValue': 0.83,
#  'lastDividendDate': 1740009600,
#  'quoteType': 'EQUITY',
#  'currentPrice': 393.08,
#  'targetHighPrice': 650.0,
#  'targetLowPrice': 420.0,
#  'targetMeanPrice': 506.242,
#  'targetMedianPrice': 500.0,
#  'recommendationMean': 1.38596,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 50,
#  'totalCash': 71554998272,
#  'totalCashPerShare': 9.625,
#  'ebitda': 142041006080,
#  'totalDebt': 102909001728,
#  'quickRatio': 1.204,
#  'currentRatio': 1.351,
#  'totalRevenue': 261802000384,
#  'debtToEquity': 33.998,
#  'revenuePerShare': 35.224,
#  'returnOnAssets': 0.14649001,
#  'returnOnEquity': 0.34291,
#  'grossProfits': 181714993152,
#  'freeCashflow': 51958124544,
#  'operatingCashflow': 125582999552,
#  'earningsGrowth': 0.102,
#  'revenueGrowth': 0.123,
#  'grossMargins': 0.69408995,
#  'ebitdaMargins': 0.54255,
#  'operatingMargins': 0.45458,
#  'financialCurrency': 'USD',
#  'symbol': 'MSFT',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'regularMarketChangePercent': 0.4651579,
#  'regularMarketPrice': 393.08,
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'corporateActions': [],
#  'postMarketTime': 1742848439,
#  'regularMarketTime': 1742846400,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_21835',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'marketState': 'POST',
#  'postMarketPrice': 392.9798,
#  'postMarketChange': -0.10018921,
#  'regularMarketChange': 1.8199768,
#  'regularMarketDayRange': '389.81 - 395.4',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 22688612,
#  'fiftyTwoWeekLowChange': 16.169983,
#  'fiftyTwoWeekLowChangePercent': 0.04290144,
#  'fiftyTwoWeekRange': '376.91 - 468.35',
#  'fiftyTwoWeekHighChange': -75.27002,
#  'fiftyTwoWeekHighChangePercent': -0.16071318,
#  'fiftyTwoWeekChangePercent': -7.4729204,
#  'dividendDate': 1749686400,
#  'earningsTimestamp': 1738184400,
#  'earningsTimestampStart': 1745438400,
#  'earningsTimestampEnd': 1745870400,
#  'earningsCallTimestampStart': 1738189800,
#  'earningsCallTimestampEnd': 1738189800,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 12.4,
#  'epsForward': 14.95,
#  'epsCurrentYear': 13.18423,
#  'priceEpsCurrentYear': 29.814405,
#  'fiftyDayAverageChange': -15.865814,
#  'fiftyDayAverageChangePercent': -0.038796864,
#  'twoHundredDayAverageChange': -30.284363,
#  'twoHundredDayAverageChangePercent': -0.07153262,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '1.4 - Strong Buy',
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 511108200000,
#  'postMarketChangePercent': -0.02548825,
#  'displayName': 'Microsoft',
#  'trailingPegRatio': 1.789}

# %%
# !conda install -c conda-forge yfinance=0.2.53 -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 25.1.1
#   latest version: 25.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.3.0
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/scrapegraph
#
#   added / updated specs:
#     - yfinance=0.2.53
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     yfinance-0.2.53            |     pyhd8ed1ab_0          89 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          89 KB
#
# The following packages will be DOWNGRADED:
#
#   yfinance                              0.2.54-pyhd8ed1ab_0 --> 0.2.53-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
ISIN = ['US9884981013','US91913Y1001','US1266501006','US23331A1097',
'US05722G1004','US4278661081','US0718131099','US9694571004','US8550301027',
'US0028241000','US69351T1060','US7445731067','US3703341046',
'US2358511028','US02209S1033','US7865142084','US85590A4013',
'US55616P1049','US25746U1097','US1491231015','US30161N1019',
'US0091581068','US3695501086','US14149Y1082','US4385161066',
'US0970231058','US74834L1008','US6819191064','US42809H1077',
'CH0048265513','US29364G1031','US7617131062','US1344291091']

# %%
import yfinance as yf

# %%
for i in ISIN:
    ticker = yf.Ticker(i)
    try:
        print(ticker.info)
    except:
        print(f"ISIN {i} delisted")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 for i in ISIN:
# ----> 2     ticker = yf.Ticker(i)
#       3     try:
#       4         print(ticker.info)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/ticker.py:35, in Ticker.__init__(self, ticker, session, proxy)
#      34 def __init__(self, ticker, session=None, proxy=None):
# ---> 35     super(Ticker, self).__init__(ticker, session=session, proxy=proxy)
#      36     self._expirations = {}
#      37     self._underlying  = {}
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/base.py:64, in TickerBase.__init__(self, ticker, session, proxy)
#      62 # accept isin as ticker
#      63 if utils.is_isin(self.ticker):
# ---> 64     self.ticker = utils.get_ticker_by_isin(self.ticker, None, session)
#      66 self._data: YfData = YfData(session=session)
#      68 # self._price_history = PriceHistory(self._data, self.ticker)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/utils.py:216, in get_ticker_by_isin(isin, proxy, session)
#     215 def get_ticker_by_isin(isin, proxy=None, session=None):
# --> 216     data = get_all_by_isin(isin, proxy, session)
#     217     return data.get('ticker', {}).get('symbol', '')
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/utils.py:197, in get_all_by_isin(isin, proxy, session)
#     194 from .search import Search
#     196 session = session or _requests
# --> 197 search = Search(query=isin, max_results=1, session=session, proxy=proxy)
#     199 # Extract the first quote and news
#     200 ticker = search.quotes[0] if search.quotes else {}
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/search.py:79, in Search.__init__(self, query, max_results, news_count, lists_count, include_cb, include_nav_links, include_research, include_cultural_assets, enable_fuzzy_query, recommended, session, proxy, timeout, raise_errors)
#      76 self._research = []
#      77 self._nav = []
# ---> 79 self.search()
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/search.py:101, in Search.search(self)
#      84 params = {
#      85     "q": self.query,
#      86     "quotesCount": self.max_results,
#    (...)     96     "recommendedCount": self.recommended
#      97 }
#      99 self._logger.debug(f'{self.query}: Yahoo GET parameters: {str(dict(params))}')
# --> 101 data = self._data.cache_get(url=url, params=params, proxy=self.proxy, timeout=self.timeout)
#     102 if data is None or "Will be right back" in data.text:
#     103     raise RuntimeError("*** YAHOO! FINANCE IS CURRENTLY DOWN! ***\n"
#     104                        "Our engineers are working quickly to resolve "
#     105                        "the issue. Thank you for your patience.")
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/data.py:30, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      28 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      29 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 30 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/data.py:413, in YfData.cache_get(self, url, user_agent_headers, params, proxy, timeout)
#     410 @lru_cache_freezeargs
#     411 @lru_cache(maxsize=cache_maxsize)
#     412 def cache_get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 413     return self.get(url, user_agent_headers, params, proxy, timeout)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/data.py:344, in YfData.get(self, url, user_agent_headers, params, proxy, timeout)
#     342 @utils.log_indent_decorator
#     343 def get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 344     return self._make_request(url, request_method = self._session.get, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/data.py:396, in YfData._make_request(self, url, request_method, user_agent_headers, body, params, proxy, timeout)
#     394     self._set_cookie_strategy('csrf')
#     395 else:
# --> 396     self._set_cookie_strategy('basic')
#     397 cookie, crumb, strategy = self._get_cookie_and_crumb(proxy, timeout)
#     398 request_args['params']['crumb'] = crumb
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/yfinance/data.py:105, in YfData._set_cookie_strategy(self, strategy, have_lock)
#     103 if self._cookie_strategy == 'csrf':
#     104     utils.get_yf_logger().debug(f'toggling cookie strategy {self._cookie_strategy} -> basic')
# --> 105     self._session.cookies.clear()
#     106     self._cookie_strategy = 'basic'
#     107 else:
#
# AttributeError: module 'requests.cookies' has no attribute 'clear'

# %%
import investpy

df = investpy.stocks.search_stocks(by='isin', value=ISIN[1])

# %%
from time import sleep
from tqdm.notebook import tqdm
list_df = []
delisted = []

for i in tqdm(ISIN):
    try:
        df = investpy.stocks.search_stocks(by='isin', value=i)
        list_df.append(df)
    except:
        delisted.append(i)
        print(f"ISIN {i} delisted")
    sleep(0.5)
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]
# ISIN US8550301027 delisted
# ISIN US7865142084 delisted
# ISIN US85590A4013 delisted
# ISIN US7617131062 delisted

# %%
list_df
# Out:
# [         country         name        full_name          isin currency symbol
#  0  united states  Yum! Brands  Yum! Brands Inc  US9884981013      USD    YUM,
#           country           name                  full_name          isin  \
#  0         mexico  Valero Energy         Valero Energy Corp  US91913Y1001
#  1  united states  Valero Energy  Valero Energy Corporation  US91913Y1001
#  2        germany  Valero Energy         Valero Energy Corp  US91913Y1001
#
#    currency symbol
#  0      MXN    VLO
#  1      USD    VLO
#  2      EUR    V1L  ,
#           country             name        full_name          isin currency  \
#  0          chile  CVS Health Corp  CVS Health Corp  US1266501006      USD
#  1         mexico  CVS Health Corp  CVS Health Corp  US1266501006      MXN
#  2  united states  CVS Health Corp  CVS Health Corp  US1266501006      USD
#  3        germany  CVS Health Corp  CVS Health Corp  US1266501006      EUR
#
#    symbol
#  0    CVS
#  1    CVS
#  2    CVS
#  3    CVS  ,
#           country       name      full_name          isin currency symbol
#  0  united states  DR Horton  DR Horton Inc  US23331A1097      USD    DHI,
#           country            name                      full_name          isin  \
#  0  united states  Baker Hughes A  Baker Hughes A Ge Company LLC  US05722G1004
#
#    currency symbol
#  0      USD    BKR  ,
#           country     name        full_name          isin currency symbol
#  0  united states  Hershey  Hershey Company  US4278661081      USD    HSY
#  1        germany  Hershey       Hershey Co  US4278661081      EUR    HSY,
#           country    name                 full_name          isin currency  \
#  0         mexico  Baxter  Baxter International Inc  US0718131099      MXN
#  1  united states  Baxter  Baxter International Inc  US0718131099      USD
#
#    symbol
#  0    BAX
#  1    BAX  ,
#           country      name               full_name          isin currency  \
#  0  united states  Williams  Williams Companies Inc  US9694571004      USD
#
#    symbol
#  0    WMB  ,
#           country         name            full_name          isin currency  \
#  0         mexico  Abbott Labs  Abbott Laboratories  US0028241000      MXN
#  1  united states  Abbott Labs  Abbott Laboratories  US0028241000      USD
#  2        germany  Abbott Labs  Abbott Laboratories  US0028241000      EUR
#  3    switzerland  Abbott Labs  Abbott Laboratories  US0028241000      CHF
#
#    symbol
#  0    ABT
#  1    ABT
#  2    ABT
#  3    ABT  ,
#           country name        full_name          isin currency symbol
#  0  united states  PPL  PPL Corporation  US69351T1060      USD    PPL,
#           country                       name  \
#  0  united states  Public Service Enterprise
#  1        germany  Public Service Enterprise
#
#                               full_name          isin currency symbol
#  0  Public Service Enterprise Group Inc  US7445731067      USD    PEG
#  1  Public Service Enterprise Group Inc  US7445731067      EUR    PEG  ,
#           country           name          full_name          isin currency  \
#  0  united states  General Mills  General Mills Inc  US3703341046      USD
#  1        austria  General Mills  General Mills Inc  US3703341046      EUR
#  2    switzerland  General Mills  General Mills Inc  US3703341046      CHF
#
#    symbol
#  0    GIS
#  1    GIS
#  2    GIS  ,
#           country     name            full_name          isin currency symbol
#  0         mexico  Danaher         Danaher Corp  US2358511028      MXN    DHR
#  1  united states  Danaher  Danaher Corporation  US2358511028      USD    DHR,
#           country    name         full_name          isin currency symbol
#  0         mexico  Altria  Altria Group Inc  US02209S1033      MXN     MO
#  1  united states  Altria      Altria Group  US02209S1033      USD     MO
#  2        austria  Altria  Altria Group Inc  US02209S1033      EUR     MO
#  3    switzerland  Altria  Altria Group Inc  US02209S1033      USD  MOUSD
#  4    switzerland  Altria  Altria Group Inc  US02209S1033      CHF     MO,
#           country        name   full_name          isin currency symbol
#  0         mexico  Macy’s Inc  Macy’s Inc  US55616P1049      MXN      M
#  1  united states  Macy’s Inc  Macy’s Inc  US55616P1049      USD      M
#  2        austria  Macy’s Inc  Macy's Inc  US55616P1049      EUR      M,
#           country             name               full_name          isin  \
#  0  united states  Dominion Energy     Dominion Energy Inc  US25746U1097
#  1        germany  Dominion Energy  Dominion Resources Inc  US25746U1097
#
#    currency symbol
#  0      USD      D
#  1      EUR      D  ,
#           country         name        full_name          isin currency symbol
#  0         mexico  Caterpillar  Caterpillar Inc  US1491231015      MXN    CAT
#  1  united states  Caterpillar  Caterpillar Inc  US1491231015      USD    CAT
#  2        austria  Caterpillar  Caterpillar Inc  US1491231015      EUR    CAT
#  3         france  Caterpillar  Caterpillar Inc  US1491231015      EUR   CATR
#  4    switzerland  Caterpillar  Caterpillar Inc  US1491231015      CHF    CAT,
#           country    name           full_name          isin currency symbol
#  0         mexico  Exelon         Exelon Corp  US30161N1019      MXN    EXC
#  1  united states  Exelon  Exelon Corporation  US30161N1019      USD    EXC,
#           country          name                       full_name          isin  \
#  0  united states  Air Products  Air Products and Chemicals Inc  US0091581068
#  1        germany  Air Products  Air Products and Chemicals Inc  US0091581068
#
#    currency symbol
#  0      USD    APD
#  1      EUR    APD  ,
#           country              name                     full_name  \
#  0         mexico  General Dynamics         General Dynamics Corp
#  1  united states  General Dynamics  General Dynamics Corporation
#
#             isin currency symbol
#  0  US3695501086      MXN     GD
#  1  US3695501086      USD     GD  ,
#           country             name            full_name          isin currency  \
#  0  united states  Cardinal Health  Cardinal Health Inc  US14149Y1082      USD
#  1        germany  Cardinal Health   Cardinal Health MU  US14149Y1082      EUR
#
#    symbol
#  0    CAH
#  1    CAH  ,
#           country       name                    full_name          isin  \
#  0         mexico  Honeywell  Honeywell International Inc  US4385161066
#  1  united states  Honeywell  Honeywell International Inc  US4385161066
#  2        germany  Honeywell   Honeywell International MU  US4385161066
#
#    currency symbol
#  0      MXN    HON
#  1      USD    HON
#  2      EUR    HON  ,
#           country    name       full_name          isin currency symbol
#  0         mexico  Boeing  Boeing Company  US0970231058      MXN     BA
#  1  united states  Boeing       Boeing Co  US0970231058      USD     BA
#  2        austria  Boeing       Boeing Co  US0970231058      EUR     BA
#  3    switzerland  Boeing       Boeing Co  US0970231058      CHF     BA
#  4    switzerland  Boeing       Boeing Co  US0970231058      EUR  BAUSD,
#           country               name                       full_name  \
#  0  united states  Quest Diagnostics  Quest Diagnostics Incorporated
#
#             isin currency symbol
#  0  US74834L1008      USD    DGX  ,
#           country     name          full_name          isin currency symbol
#  0  united states  Omnicom  Omnicom Group Inc  US6819191064      USD    OMC,
#           country  name         full_name          isin currency symbol
#  0  united states  Hess  Hess Corporation  US42809H1077      USD    HES,
#           country        name       full_name          isin currency   symbol
#  0         mexico  Transocean  Transocean Ltd  CH0048265513      MXN     RIGN
#  1  united states  Transocean  Transocean Ltd  CH0048265513      USD      RIG
#  2    switzerland  Transocean  Transocean Ltd  CH0048265513      CHF     RIGN
#  3    switzerland  Transocean  Transocean Ltd  CH0048265513      USD  RIGNUSD,
#           country     name            full_name          isin currency symbol
#  0  united states  Entergy  Entergy Corporation  US29364G1031      USD    ETR,
#           country           name              full_name          isin currency  \
#  0  united states  Campbell Soup  Campbell Soup Company  US1344291091      USD
#
#    symbol
#  0    CPB  ]

# %%
import pandas as pd

# %%
cdf = pd.concat(list_df)

# %%
cdf.loc[cdf['country']=='united states','isin'].unique()
# some ISINs may not be in the united states
# Out:
# array(['US9884981013', 'US91913Y1001', 'US1266501006', 'US23331A1097',
#        'US05722G1004', 'US4278661081', 'US0718131099', 'US9694571004',
#        'US0028241000', 'US69351T1060', 'US7445731067', 'US3703341046',
#        'US2358511028', 'US02209S1033', 'US55616P1049', 'US25746U1097',
#        'US1491231015', 'US30161N1019', 'US0091581068', 'US3695501086',
#        'US14149Y1082', 'US4385161066', 'US0970231058', 'US74834L1008',
#        'US6819191064', 'US42809H1077', 'CH0048265513', 'US29364G1031',
#        'US1344291091'], dtype=object)
