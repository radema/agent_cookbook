# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from scrapegraphai.graphs import SmartScraperGraph

# Define the configuration for the scraping pipeline
graph_config = {
    "llm": {
        "model": "ollama/llama3.2:3b",
        "model_tokens": 8192
    },
    "verbose": True,
    "headless": False,
}

# Create the SmartScraperGraph instance
smart_scraper_graph = SmartScraperGraph(
    prompt="Extract useful information from the webpage, including a description of what the company does, founders and social media links",
    source="https://scrapegraphai.com/",
    config=graph_config
)

# Run the pipeline
result = smart_scraper_graph.run()

import json
print(json.dumps(result, indent=4))
# Out:
# --- Executing Fetch Node ---
# --- (Fetching HTML from: https://scrapegraphai.com/) ---
# --- Executing ParseNode Node ---
# --- Executing GenerateAnswer Node ---
# Error during chain execution: Invalid json output: This is a lengthy piece of text that appears to be a sales page or marketing materials for an AI-powered web scraping tool called ScrapeGraphAI. Here's a summary of the key points:
#
# **What is ScrapeGraphAI?**
# ScrapeGraphAI is a powerful AI-driven API that makes web scraping effortless for developers and AI agents.
#
# **How does it work?**
# The text doesn't provide a detailed explanation of how ScrapeGraphAI works, but it mentions that it uses Large Language Models (LLMs) to simplify the data extraction process.
#
# **Ease of integration**
# ScrapeGraphAI can be easily integrated with Python, JavaScript, and TypeScript.
#
# **Perfect for AI agents**
# ScrapeGraphAI is designed to make web scraping easier for AI agents.
#
# **Types of websites and data handled**
# ScrapeGraphAI can handle various types of websites and data, including those with complex structures or changing content.
#
# **Performance, reliability, and scalability**
# The tool is designed to provide high performance, reliability, and scalability, making it suitable for large-scale web scraping tasks.
#
# **Pricing and what's included**
# The pricing information isn't explicitly stated in the text, but it mentions that ScrapeGraphAI offers a structured data solution without the hassle of writing complex code.
#
# **Founders**
# The founders of ScrapeGraphAI are Marco Vinciguerra and Lorenzo Padoan.
#
# **Stay updated**
# Subscribers can receive updates on the latest features, releases, and community news by signing up for the newsletter.
#
# **Contact information**
# The contact information includes email (contact@scrapegraphai.com), LinkedIn profile links, GitHub repository link, and a Discord channel invitation.
#
# Overall, this text aims to promote ScrapeGraphAI as a powerful tool for web scraping, highlighting its ease of use, performance, and scalability.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/output_parsers/json.py:83, in JsonOutputParser.parse_result(self, result, partial)
#      82 try:
# ---> 83     return parse_json_markdown(text)
#      84 except JSONDecodeError as e:
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/utils/json.py:145, in parse_json_markdown(json_string, parser)
#     144     json_str = json_string if match is None else match.group(2)
# --> 145 return _parse_json(json_str, parser=parser)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/utils/json.py:161, in _parse_json(json_str, parser)
#     160 # Parse the JSON string into a Python dictionary
# --> 161 return parser(json_str)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/utils/json.py:119, in parse_partial_json(s, strict)
#     116 # If we got here, we ran out of characters to remove
#     117 # and still couldn't parse the string as JSON, so return the parse error
#     118 # for the original string.
# --> 119 return json.loads(s, strict=strict)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/json/__init__.py:359, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     358     kw['parse_constant'] = parse_constant
# --> 359 return cls(**kw).decode(s)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/json/decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/json/decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[4], line 21
#      14 smart_scraper_graph = SmartScraperGraph(
#      15     prompt="Extract useful information from the webpage, including a description of what the company does, founders and social media links",
#      16     source="https://scrapegraphai.com/",
#      17     config=graph_config
#      18 )
#      20 # Run the pipeline
# ---> 21 result = smart_scraper_graph.run()
#      23 import json
#      24 print(json.dumps(result, indent=4))
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/smart_scraper_graph.py:296, in SmartScraperGraph.run(self)
#     288 """
#     289 Executes the scraping process and returns the answer to the prompt.
#     290
#     291 Returns:
#     292     str: The answer to the prompt.
#     293 """
#     295 inputs = {"user_prompt": self.prompt, self.input_key: self.source}
# --> 296 self.final_state, self.execution_info = self.graph.execute(inputs)
#     298 return self.final_state.get("answer", "No answer found.")
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:358, in BaseGraph.execute(self, initial_state)
#     356     return (result["_state"], [])
#     357 else:
# --> 358     return self._execute_standard(initial_state)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:303, in BaseGraph._execute_standard(self, initial_state)
#     290         graph_execution_time = time.time() - start_time
#     291         log_graph_execution(
#     292             graph_name=self.graph_name,
#     293             source=source,
#    (...)    301             exception=str(e),
#     302         )
# --> 303         raise e
#     305 exec_info.append(
#     306     {
#     307         "node_name": "TOTAL RESULT",
#    (...)    314     }
#     315 )
#     317 graph_execution_time = time.time() - start_time
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:276, in BaseGraph._execute_standard(self, initial_state)
#     273     schema = self._get_schema(current_node)
#     275 try:
# --> 276     result, node_exec_time, cb_data = self._execute_node(
#     277         current_node, state, llm_model, llm_model_name
#     278     )
#     279     total_exec_time += node_exec_time
#     281     if cb_data:
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:200, in BaseGraph._execute_node(self, current_node, state, llm_model, llm_model_name)
#     195 curr_time = time.time()
#     197 with self.callback_manager.exclusive_get_callback(
#     198     llm_model, llm_model_name
#     199 ) as cb:
# --> 200     result = current_node.execute(state)
#     201     node_exec_time = time.time() - curr_time
#     203     cb_data = None
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/nodes/generate_answer_node.py:194, in GenerateAnswerNode.execute(self, state)
#     191     chain = chain | output_parser
#     193 try:
# --> 194     answer = self.invoke_with_timeout(
#     195         chain, {"question": user_prompt}, self.timeout
#     196     )
#     197 except (Timeout, json.JSONDecodeError) as e:
#     198     error_msg = (
#     199         "Response timeout exceeded"
#     200         if isinstance(e, Timeout)
#     201         else "Invalid JSON response format"
#     202     )
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/nodes/generate_answer_node.py:79, in GenerateAnswerNode.invoke_with_timeout(self, chain, inputs, timeout)
#      77 try:
#      78     start_time = time.time()
# ---> 79     response = chain.invoke(inputs)
#      80     if time.time() - start_time > timeout:
#      81         raise Timeout(f"Response took longer than {timeout} seconds")
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/runnables/base.py:3025, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3023                 input = context.run(step.invoke, input, config, **kwargs)
#    3024             else:
# -> 3025                 input = context.run(step.invoke, input, config)
#    3026 # finish the root run
#    3027 except BaseException as e:
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/output_parsers/base.py:193, in BaseOutputParser.invoke(self, input, config, **kwargs)
#     186 def invoke(
#     187     self,
#     188     input: Union[str, BaseMessage],
#     189     config: Optional[RunnableConfig] = None,
#     190     **kwargs: Any,
#     191 ) -> T:
#     192     if isinstance(input, BaseMessage):
# --> 193         return self._call_with_config(
#     194             lambda inner_input: self.parse_result(
#     195                 [ChatGeneration(message=inner_input)]
#     196             ),
#     197             input,
#     198             config,
#     199             run_type="parser",
#     200         )
#     201     else:
#     202         return self._call_with_config(
#     203             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     204             input,
#     205             config,
#     206             run_type="parser",
#     207         )
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/runnables/base.py:1925, in Runnable._call_with_config(self, func, input, config, run_type, serialized, **kwargs)
#    1921     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1922     with set_config_context(child_config) as context:
#    1923         output = cast(
#    1924             Output,
# -> 1925             context.run(
#    1926                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1927                 func,  # type: ignore[arg-type]
#    1928                 input,  # type: ignore[arg-type]
#    1929                 config,
#    1930                 run_manager,
#    1931                 **kwargs,
#    1932             ),
#    1933         )
#    1934 except BaseException as e:
#    1935     run_manager.on_chain_error(e)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/runnables/config.py:430, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     428 if run_manager is not None and accepts_run_manager(func):
#     429     kwargs["run_manager"] = run_manager
# --> 430 return func(input, **kwargs)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/output_parsers/base.py:194, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     186 def invoke(
#     187     self,
#     188     input: Union[str, BaseMessage],
#     189     config: Optional[RunnableConfig] = None,
#     190     **kwargs: Any,
#     191 ) -> T:
#     192     if isinstance(input, BaseMessage):
#     193         return self._call_with_config(
# --> 194             lambda inner_input: self.parse_result(
#     195                 [ChatGeneration(message=inner_input)]
#     196             ),
#     197             input,
#     198             config,
#     199             run_type="parser",
#     200         )
#     201     else:
#     202         return self._call_with_config(
#     203             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     204             input,
#     205             config,
#     206             run_type="parser",
#     207         )
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/output_parsers/json.py:86, in JsonOutputParser.parse_result(self, result, partial)
#      84 except JSONDecodeError as e:
#      85     msg = f"Invalid json output: {text}"
# ---> 86     raise OutputParserException(msg, llm_output=text) from e
#
# OutputParserException: Invalid json output: This is a lengthy piece of text that appears to be a sales page or marketing materials for an AI-powered web scraping tool called ScrapeGraphAI. Here's a summary of the key points:
#
# **What is ScrapeGraphAI?**
# ScrapeGraphAI is a powerful AI-driven API that makes web scraping effortless for developers and AI agents.
#
# **How does it work?**
# The text doesn't provide a detailed explanation of how ScrapeGraphAI works, but it mentions that it uses Large Language Models (LLMs) to simplify the data extraction process.
#
# **Ease of integration**
# ScrapeGraphAI can be easily integrated with Python, JavaScript, and TypeScript.
#
# **Perfect for AI agents**
# ScrapeGraphAI is designed to make web scraping easier for AI agents.
#
# **Types of websites and data handled**
# ScrapeGraphAI can handle various types of websites and data, including those with complex structures or changing content.
#
# **Performance, reliability, and scalability**
# The tool is designed to provide high performance, reliability, and scalability, making it suitable for large-scale web scraping tasks.
#
# **Pricing and what's included**
# The pricing information isn't explicitly stated in the text, but it mentions that ScrapeGraphAI offers a structured data solution without the hassle of writing complex code.
#
# **Founders**
# The founders of ScrapeGraphAI are Marco Vinciguerra and Lorenzo Padoan.
#
# **Stay updated**
# Subscribers can receive updates on the latest features, releases, and community news by signing up for the newsletter.
#
# **Contact information**
# The contact information includes email (contact@scrapegraphai.com), LinkedIn profile links, GitHub repository link, and a Discord channel invitation.
#
# Overall, this text aims to promote ScrapeGraphAI as a powerful tool for web scraping, highlighting its ease of use, performance, and scalability.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE

# %%
from scrapegraphai.graphs import SearchGraph

# Create the SearchGraph instance
search_graph = SearchGraph(
    prompt="List me all the European countries. Look in wikipedia.",
    config=graph_config
)

# %%
result = search_graph.run()
# Out:
# --- Executing SearchInternet Node ---
# Search Query: European countries listed on Wikipedia
# --- Executing GraphIterator Node with batchsize 16 ---
# processing graph instances:   0%|          | 0/4 [00:00<?, ?it/s]--- Executing Fetch Node ---
# --- Executing Fetch Node ---
# --- Executing Fetch Node ---
# --- Executing Fetch Node ---
# --- (Fetching HTML from: https://en.wikipedia.org/wiki/Flags_of_Europe) ---
# --- (Fetching HTML from: https://en.wikipedia.org/wiki/Central_Europe) ---
# --- (Fetching HTML from: https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_in_Europe) ---
# --- (Fetching HTML from: https://factsinstitute.com/countries/european-countries/) ---
# --- Executing ParseNode Node ---
# --- Executing GenerateAnswer Node ---
# Processing chunks: 100%|██████████| 9/9 [00:00<00:00, 33346.94it/s]
# --- Executing ParseNode Node ---
# --- Executing GenerateAnswer Node ---
# Processing chunks: 100%|██████████| 11/11 [00:00<00:00, 34663.67it/s]
# --- Executing ParseNode Node ---
# --- Executing ParseNode Node ---
# --- Executing GenerateAnswer Node ---
# --- Executing GenerateAnswer Node ---
# Processing chunks: 100%|██████████| 14/14 [00:00<00:00, 48933.55it/s]
# Error during chain execution: Invalid json output: Yoruba is a list of states in Europe.
#
# * Àkójọ àwọn orílẹ̀-èdè Europe
# * Àkójọ àwọn orílẹ̀-èdè Europe (alternative)
# * Àkójọ àwọn orílẹ̀-èdè Africa
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# processing graph instances:   0%|          | 0/4 [05:00<?, ?it/s]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/output_parsers/json.py:83, in JsonOutputParser.parse_result(self, result, partial)
#      82 try:
# ---> 83     return parse_json_markdown(text)
#      84 except JSONDecodeError as e:
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/utils/json.py:145, in parse_json_markdown(json_string, parser)
#     144     json_str = json_string if match is None else match.group(2)
# --> 145 return _parse_json(json_str, parser=parser)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/utils/json.py:161, in _parse_json(json_str, parser)
#     160 # Parse the JSON string into a Python dictionary
# --> 161 return parser(json_str)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/utils/json.py:119, in parse_partial_json(s, strict)
#     116 # If we got here, we ran out of characters to remove
#     117 # and still couldn't parse the string as JSON, so return the parse error
#     118 # for the original string.
# --> 119 return json.loads(s, strict=strict)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/json/__init__.py:359, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     358     kw['parse_constant'] = parse_constant
# --> 359 return cls(**kw).decode(s)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/json/decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/json/decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = search_graph.run()
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/search_graph.py:112, in SearchGraph.run(self)
#     104 """
#     105 Executes the web scraping and searching process.
#     106
#     107 Returns:
#     108     str: The answer to the prompt.
#     109 """
#     111 inputs = {"user_prompt": self.prompt}
# --> 112 self.final_state, self.execution_info = self.graph.execute(inputs)
#     114 # Store the URLs after execution
#     115 if "urls" in self.final_state:
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:358, in BaseGraph.execute(self, initial_state)
#     356     return (result["_state"], [])
#     357 else:
# --> 358     return self._execute_standard(initial_state)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:303, in BaseGraph._execute_standard(self, initial_state)
#     290         graph_execution_time = time.time() - start_time
#     291         log_graph_execution(
#     292             graph_name=self.graph_name,
#     293             source=source,
#    (...)    301             exception=str(e),
#     302         )
# --> 303         raise e
#     305 exec_info.append(
#     306     {
#     307         "node_name": "TOTAL RESULT",
#    (...)    314     }
#     315 )
#     317 graph_execution_time = time.time() - start_time
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:276, in BaseGraph._execute_standard(self, initial_state)
#     273     schema = self._get_schema(current_node)
#     275 try:
# --> 276     result, node_exec_time, cb_data = self._execute_node(
#     277         current_node, state, llm_model, llm_model_name
#     278     )
#     279     total_exec_time += node_exec_time
#     281     if cb_data:
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:200, in BaseGraph._execute_node(self, current_node, state, llm_model, llm_model_name)
#     195 curr_time = time.time()
#     197 with self.callback_manager.exclusive_get_callback(
#     198     llm_model, llm_model_name
#     199 ) as cb:
# --> 200     result = current_node.execute(state)
#     201     node_exec_time = time.time() - curr_time
#     203     cb_data = None
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/nodes/graph_iterator_node.py:75, in GraphIteratorNode.execute(self, state)
#      72     eventloop = None
#      74 if eventloop and eventloop.is_running():
# ---> 75     state = eventloop.run_until_complete(self._async_execute(state, batchsize))
#      76 else:
#      77     state = asyncio.run(self._async_execute(state, batchsize))
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/asyncio/futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/asyncio/tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/nodes/graph_iterator_node.py:141, in GraphIteratorNode._async_execute(self, state, batchsize)
#     137     participants.append(graph)
#     139 futures = [_async_run(graph) for graph in participants]
# --> 141 answers = await tqdm.gather(
#     142     *futures, desc="processing graph instances", disable=not self.verbose
#     143 )
#     145 state.update({self.output[0]: answers})
#     147 return state
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/tqdm/asyncio.py:79, in tqdm_asyncio.gather(cls, loop, timeout, total, *fs, **tqdm_kwargs)
#      76     return i, await f
#      78 ifs = [wrap_awaitable(i, f) for i, f in enumerate(fs)]
# ---> 79 res = [await f for f in cls.as_completed(ifs, loop=loop, timeout=timeout,
#      80                                          total=total, **tqdm_kwargs)]
#      81 return [i for _, i in sorted(res)]
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/asyncio/tasks.py:634, in _AsCompletedIterator._wait_for_one(self, resolve)
#     631 if f is None:
#     632     # Dummy value from _handle_timeout().
#     633     raise exceptions.TimeoutError
# --> 634 return f.result() if resolve else f
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/asyncio/futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/asyncio/tasks.py:306, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     304         result = coro.send(None)
#     305     else:
# --> 306         result = coro.throw(exc)
#     307 except StopIteration as exc:
#     308     if self._must_cancel:
#     309         # Task is cancelled right before coro stops.
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/tqdm/asyncio.py:76, in tqdm_asyncio.gather.<locals>.wrap_awaitable(i, f)
#      75 async def wrap_awaitable(i, f):
# ---> 76     return i, await f
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/nodes/graph_iterator_node.py:131, in GraphIteratorNode._async_execute.<locals>._async_run(graph)
#     129 async def _async_run(graph):
#     130     async with semaphore:
# --> 131         return await asyncio.to_thread(graph.run)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/asyncio/threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/asyncio/futures.py:286, in Future.__await__(self)
#     284 if not self.done():
#     285     self._asyncio_future_blocking = True
# --> 286     yield self  # This tells Task to wait for completion.
#     287 if not self.done():
#     288     raise RuntimeError("await wasn't used with future")
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/asyncio/tasks.py:375, in Task.__wakeup(self, future)
#     373 def __wakeup(self, future):
#     374     try:
# --> 375         future.result()
#     376     except BaseException as exc:
#     377         # This may also be a cancellation.
#     378         self.__step(exc)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/asyncio/futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/smart_scraper_graph.py:296, in SmartScraperGraph.run(self)
#     288 """
#     289 Executes the scraping process and returns the answer to the prompt.
#     290
#     291 Returns:
#     292     str: The answer to the prompt.
#     293 """
#     295 inputs = {"user_prompt": self.prompt, self.input_key: self.source}
# --> 296 self.final_state, self.execution_info = self.graph.execute(inputs)
#     298 return self.final_state.get("answer", "No answer found.")
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:358, in BaseGraph.execute(self, initial_state)
#     356     return (result["_state"], [])
#     357 else:
# --> 358     return self._execute_standard(initial_state)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:303, in BaseGraph._execute_standard(self, initial_state)
#     290         graph_execution_time = time.time() - start_time
#     291         log_graph_execution(
#     292             graph_name=self.graph_name,
#     293             source=source,
#    (...)    301             exception=str(e),
#     302         )
# --> 303         raise e
#     305 exec_info.append(
#     306     {
#     307         "node_name": "TOTAL RESULT",
#    (...)    314     }
#     315 )
#     317 graph_execution_time = time.time() - start_time
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:276, in BaseGraph._execute_standard(self, initial_state)
#     273     schema = self._get_schema(current_node)
#     275 try:
# --> 276     result, node_exec_time, cb_data = self._execute_node(
#     277         current_node, state, llm_model, llm_model_name
#     278     )
#     279     total_exec_time += node_exec_time
#     281     if cb_data:
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/graphs/base_graph.py:200, in BaseGraph._execute_node(self, current_node, state, llm_model, llm_model_name)
#     195 curr_time = time.time()
#     197 with self.callback_manager.exclusive_get_callback(
#     198     llm_model, llm_model_name
#     199 ) as cb:
# --> 200     result = current_node.execute(state)
#     201     node_exec_time = time.time() - curr_time
#     203     cb_data = None
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/nodes/generate_answer_node.py:231, in GenerateAnswerNode.execute(self, state)
#     229 async_runner = RunnableParallel(**chains_dict)
#     230 try:
# --> 231     batch_results = self.invoke_with_timeout(
#     232         async_runner, {"question": user_prompt}, self.timeout
#     233     )
#     234 except (Timeout, json.JSONDecodeError) as e:
#     235     error_msg = (
#     236         "Response timeout exceeded during chunk processing"
#     237         if isinstance(e, Timeout)
#     238         else "Invalid JSON response format in chunk processing"
#     239     )
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/scrapegraphai/nodes/generate_answer_node.py:79, in GenerateAnswerNode.invoke_with_timeout(self, chain, inputs, timeout)
#      77 try:
#      78     start_time = time.time()
# ---> 79     response = chain.invoke(inputs)
#      80     if time.time() - start_time > timeout:
#      81         raise Timeout(f"Response took longer than {timeout} seconds")
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/runnables/base.py:3728, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3723     with get_executor_for_config(config) as executor:
#    3724         futures = [
#    3725             executor.submit(_invoke_step, step, input, config, key)
#    3726             for key, step in steps.items()
#    3727         ]
# -> 3728         output = {key: future.result() for key, future in zip(steps, futures)}
#    3729 # finish the root run
#    3730 except BaseException as e:
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/runnables/base.py:3712, in RunnableParallel.invoke.<locals>._invoke_step(step, input, config, key)
#    3706 child_config = patch_config(
#    3707     config,
#    3708     # mark each step as a child run
#    3709     callbacks=run_manager.get_child(f"map:key:{key}"),
#    3710 )
#    3711 with set_config_context(child_config) as context:
# -> 3712     return context.run(
#    3713         step.invoke,
#    3714         input,
#    3715         child_config,
#    3716     )
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/runnables/base.py:3025, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3023                 input = context.run(step.invoke, input, config, **kwargs)
#    3024             else:
# -> 3025                 input = context.run(step.invoke, input, config)
#    3026 # finish the root run
#    3027 except BaseException as e:
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/output_parsers/base.py:193, in BaseOutputParser.invoke(self, input, config, **kwargs)
#     186 def invoke(
#     187     self,
#     188     input: Union[str, BaseMessage],
#     189     config: Optional[RunnableConfig] = None,
#     190     **kwargs: Any,
#     191 ) -> T:
#     192     if isinstance(input, BaseMessage):
# --> 193         return self._call_with_config(
#     194             lambda inner_input: self.parse_result(
#     195                 [ChatGeneration(message=inner_input)]
#     196             ),
#     197             input,
#     198             config,
#     199             run_type="parser",
#     200         )
#     201     else:
#     202         return self._call_with_config(
#     203             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     204             input,
#     205             config,
#     206             run_type="parser",
#     207         )
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/runnables/base.py:1925, in Runnable._call_with_config(self, func, input, config, run_type, serialized, **kwargs)
#    1921     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1922     with set_config_context(child_config) as context:
#    1923         output = cast(
#    1924             Output,
# -> 1925             context.run(
#    1926                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1927                 func,  # type: ignore[arg-type]
#    1928                 input,  # type: ignore[arg-type]
#    1929                 config,
#    1930                 run_manager,
#    1931                 **kwargs,
#    1932             ),
#    1933         )
#    1934 except BaseException as e:
#    1935     run_manager.on_chain_error(e)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/runnables/config.py:430, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     428 if run_manager is not None and accepts_run_manager(func):
#     429     kwargs["run_manager"] = run_manager
# --> 430 return func(input, **kwargs)
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/output_parsers/base.py:194, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     186 def invoke(
#     187     self,
#     188     input: Union[str, BaseMessage],
#     189     config: Optional[RunnableConfig] = None,
#     190     **kwargs: Any,
#     191 ) -> T:
#     192     if isinstance(input, BaseMessage):
#     193         return self._call_with_config(
# --> 194             lambda inner_input: self.parse_result(
#     195                 [ChatGeneration(message=inner_input)]
#     196             ),
#     197             input,
#     198             config,
#     199             run_type="parser",
#     200         )
#     201     else:
#     202         return self._call_with_config(
#     203             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     204             input,
#     205             config,
#     206             run_type="parser",
#     207         )
#
# File /opt/anaconda3/envs/scrapegraph/lib/python3.13/site-packages/langchain_core/output_parsers/json.py:86, in JsonOutputParser.parse_result(self, result, partial)
#      84 except JSONDecodeError as e:
#      85     msg = f"Invalid json output: {text}"
# ---> 86     raise OutputParserException(msg, llm_output=text) from e
#
# OutputParserException: Invalid json output: Yoruba is a list of states in Europe.
#
# * Àkójọ àwọn orílẹ̀-èdè Europe
# * Àkójọ àwọn orílẹ̀-èdè Europe (alternative)
# * Àkójọ àwọn orílẹ̀-èdè Africa
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Error during chain execution: Invalid json output: The text appears to be a Wikipedia-style article about countries, specifically Europe. It includes information on the number of countries in Europe, which is 50.
#
# Here are the key points from the article:
#
# 1. There are 50 sovereign states in Europe.
# 2. The countries listed include Austria, Belgium, Bulgaria, Croatia, Cyprus, Czech Republic, Denmark, Estonia, Finland, France, Georgia, Germany, Greece, Hungary, Iceland, Ireland, Italy, Latvia, Liechtenstein, Lithuania, Luxembourg, Malta, Moldova, Monaco, Montenegro, Netherlands, North Macedonia, Norway, Poland, Portugal, Romania, San Marino, Serbia, Slovakia, Slovenia, Spain, Sweden, Switzerland, Turkey, and Ukraine.
# 3. The article includes a list of all 50 countries in Europe, along with their capital cities and other relevant information.
# 4. The text also includes information on the number of languages spoken in each country, as well as the total population of Europe.
#
# However, it's worth noting that the article appears to be incomplete, with many sections missing or blank. Additionally, some of the information provided is outdated or incorrect.
#
# It's always a good idea to verify information through reputable sources when researching countries or any other topic.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Error during chain execution: Invalid json output: The text is a list of languages and dialects that use the term "Central Europe" or its variants to refer to the region. It includes a wide range of languages from across Europe, including:
#
# * Slavic languages: Ukrainian, Russian, Polish
# * Germanic languages: German, Dutch, Flemish
# * Romance languages: French, Italian, Spanish
# * Celtic languages: Welsh, Breton
# * Indo-Iranian languages: Hindi, Urdu
# * Turkic languages: Turkish, Azerbaijani
# * Uralic languages: Hungarian
# * Finno-Ugric languages: Finnish
# * Baltic languages: Latvian, Lithuanian
# * Greek
# * Albanian
# * Armenian
# * Basque
# * And many others
#
# The list also includes some dialects and regional variants of languages, such as:
#
# * Venetian (Italy)
# * Waray (Philippines)
# * Wu (China)
# * Yoruba (Nigeria)
# * Zeelandic (Netherlands)
#
# Overall, the text provides a diverse representation of languages and dialects used to refer to Central Europe.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Error during chain execution: Invalid json output: The text lists flags used in Europe, including supranational and international flags, as well as flags of European sovereign states. The list includes:
#
# * Supranational and international flags:
# 	+ Flag of the Benelux (1957-1958)
# 	+ Flag of the Central Commission for Navigation on the Rhine
# 	+ Flag of CEFTA (1990s-present)
# 	+ Flag of the Commonwealth of Independent States (1991-present)
# 	+ Flag of Europe (1955-)
# 	+ Flag of the European Union (1986-present)
# 	+ Flag of the European Parliament (1973-1983)
# 	+ Flag of the Nordic Council
# 	+ Flag of NATO (1953-)
# 	+ Flag of the European Gendarmerie Force
# 	+ Flag of the European Maritime Force
# * Flags of European sovereign states:
# 	+ (List not provided in the text)
#
# Note that the list is incomplete, and there may be other flags used in Europe that are not included.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE

# %%
import json

output = json.dumps(result, indent=2)

line_list = output.split("\n")  # Sort of line replacing "\n" with a new line

for line in line_list:
    print(line)
